# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=0ccb1b7897f1bab39b6cd54104d4f380

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
# Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
# Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
# Convert the date to ISO standard.
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
# Append the city information into city_data list.
        city_data.append({"City": city.title(),
                    "Lat": city_lat,
                    "Lng": city_lng,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Country": city_country,
                    "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | santa rosa
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | codajas
# Processing Record 4 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 1 | melo
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | tarko-sale
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | oktyabrskoye
# Processing Record 11 of Set 1 | matata
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | lamar
# Processing Record 15 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 1 | moree
# Processing Record 17 of Set 1 | yumen
# Processing Record 18 of Set 1 | formosa
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | jieshi
# Processing Record 22 of Set 1 | ayagoz
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | cooma
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | hauterive
# Processing Record 36 of Set 1 | daxian
# City not found. Skipping...
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | calamar
# Processing Record 41 of Set 1 | coos bay
# Processing Record 42 of Set 1 | high level
# Processing Record 43 of Set 1 | matara
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | sistranda
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | inhambane
# Processing Record 2 of Set 2 | trzebnica
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | alice springs
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | pangnirtung
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | barranca
# Processing Record 10 of Set 2 | lubliniec
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | jacksonville beach
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | madang
# Processing Record 17 of Set 2 | burica
# City not found. Skipping...
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | nanortalik
# Processing Record 20 of Set 2 | matamoros
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | olafsvik
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 2 | biak
# Processing Record 31 of Set 2 | isangel
# Processing Record 32 of Set 2 | tecoanapa
# Processing Record 33 of Set 2 | andros town
# Processing Record 34 of Set 2 | lorengau
# Processing Record 35 of Set 2 | murgab
# Processing Record 36 of Set 2 | omagari
# Processing Record 37 of Set 2 | mayumba
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | daitari
# Processing Record 41 of Set 2 | coahuayana
# Processing Record 42 of Set 2 | macamic
# Processing Record 43 of Set 2 | santa cruz de la palma
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | mount isa
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | isabela
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | russell
# Processing Record 3 of Set 3 | pacific grove
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | srednekolymsk
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | salalah
# Processing Record 8 of Set 3 | goure
# Processing Record 9 of Set 3 | thanh hoa
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | yerbogachen
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | faya
# Processing Record 16 of Set 3 | novyy urengoy
# Processing Record 17 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | jaguaribe
# Processing Record 22 of Set 3 | bundoran
# Processing Record 23 of Set 3 | ilheus
# Processing Record 24 of Set 3 | korla
# Processing Record 25 of Set 3 | vanimo
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | la orilla
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | kununurra
# Processing Record 30 of Set 3 | tuatapere
# Processing Record 31 of Set 3 | burnie
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 3 | meadow lake
# Processing Record 35 of Set 3 | muros
# Processing Record 36 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | namwala
# Processing Record 39 of Set 3 | hualmay
# Processing Record 40 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 41 of Set 3 | kieta
# Processing Record 42 of Set 3 | sepolno krajenskie
# Processing Record 43 of Set 3 | linxi
# Processing Record 44 of Set 3 | leova
# Processing Record 45 of Set 3 | vice
# Processing Record 46 of Set 3 | arlit
# Processing Record 47 of Set 3 | swift current
# Processing Record 48 of Set 3 | ouesso
# Processing Record 49 of Set 3 | harper
# Processing Record 50 of Set 3 | firminy
# Processing Record 1 of Set 4 | port alfred
# Processing Record 2 of Set 4 | katsuura
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | landsberg
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | melnikovo
# Processing Record 8 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 4 | khorixas
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | kloulklubed
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | laguna
# Processing Record 14 of Set 4 | odweyne
# Processing Record 15 of Set 4 | verkhnetulomskiy
# Processing Record 16 of Set 4 | hami
# Processing Record 17 of Set 4 | matrei
# City not found. Skipping...
# Processing Record 18 of Set 4 | jamestown
# Processing Record 19 of Set 4 | zeya
# Processing Record 20 of Set 4 | parras
# City not found. Skipping...
# Processing Record 21 of Set 4 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 4 | sao raimundo nonato
# Processing Record 23 of Set 4 | hay river
# Processing Record 24 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 4 | vila
# Processing Record 26 of Set 4 | songea
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | beringovskiy
# Processing Record 29 of Set 4 | ridgecrest
# Processing Record 30 of Set 4 | port lincoln
# Processing Record 31 of Set 4 | baykit
# Processing Record 32 of Set 4 | finnsnes
# Processing Record 33 of Set 4 | bireun
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | jinchang
# Processing Record 37 of Set 4 | namibe
# Processing Record 38 of Set 4 | kruisfontein
# Processing Record 39 of Set 4 | adrar
# Processing Record 40 of Set 4 | nidau
# Processing Record 41 of Set 4 | lethem
# Processing Record 42 of Set 4 | axim
# Processing Record 43 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 4 | clinton
# Processing Record 45 of Set 4 | galich
# Processing Record 46 of Set 4 | aklavik
# Processing Record 47 of Set 4 | najran
# Processing Record 48 of Set 4 | teknaf
# Processing Record 49 of Set 4 | kangaatsiaq
# Processing Record 50 of Set 4 | camacha
# Processing Record 1 of Set 5 | faridan
# City not found. Skipping...
# Processing Record 2 of Set 5 | rouvroy
# Processing Record 3 of Set 5 | lapua
# Processing Record 4 of Set 5 | bambous virieux
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | halifax
# Processing Record 7 of Set 5 | trincomalee
# Processing Record 8 of Set 5 | novo aripuana
# Processing Record 9 of Set 5 | road town
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | chino valley
# Processing Record 12 of Set 5 | xuddur
# Processing Record 13 of Set 5 | portland
# Processing Record 14 of Set 5 | cabo san lucas
# Processing Record 15 of Set 5 | tabory
# Processing Record 16 of Set 5 | tiznit
# Processing Record 17 of Set 5 | saintes
# Processing Record 18 of Set 5 | gat
# Processing Record 19 of Set 5 | tilichiki
# Processing Record 20 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 5 | kamiiso
# Processing Record 22 of Set 5 | the pas
# Processing Record 23 of Set 5 | vilyuysk
# Processing Record 24 of Set 5 | kobojango
# City not found. Skipping...
# Processing Record 25 of Set 5 | qianguo
# Processing Record 26 of Set 5 | half moon bay
# Processing Record 27 of Set 5 | padang
# Processing Record 28 of Set 5 | walvis bay
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | hailar
# Processing Record 31 of Set 5 | bonavista
# Processing Record 32 of Set 5 | lugovoy
# Processing Record 33 of Set 5 | payakumbuh
# Processing Record 34 of Set 5 | lavrentiya
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | bayan
# Processing Record 37 of Set 5 | novopokrovka
# Processing Record 38 of Set 5 | ilulissat
# Processing Record 39 of Set 5 | shellbrook
# Processing Record 40 of Set 5 | grindavik
# Processing Record 41 of Set 5 | mount gambier
# Processing Record 42 of Set 5 | tabas
# Processing Record 43 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 5 | lompoc
# Processing Record 45 of Set 5 | port said
# Processing Record 46 of Set 5 | marawi
# Processing Record 47 of Set 5 | bollnas
# Processing Record 48 of Set 5 | joetsu
# Processing Record 49 of Set 5 | vila do maio
# Processing Record 50 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 6 | esmeralda
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | karratha
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | cazzago san martino
# Processing Record 6 of Set 6 | huilong
# Processing Record 7 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 8 of Set 6 | karwar
# Processing Record 9 of Set 6 | kuminskiy
# Processing Record 10 of Set 6 | port-gentil
# Processing Record 11 of Set 6 | ostersund
# Processing Record 12 of Set 6 | mercedes
# Processing Record 13 of Set 6 | manggar
# Processing Record 14 of Set 6 | wanning
# Processing Record 15 of Set 6 | awjilah
# Processing Record 16 of Set 6 | batagay
# Processing Record 17 of Set 6 | saint combs
# City not found. Skipping...
# Processing Record 18 of Set 6 | dunedin
# Processing Record 19 of Set 6 | los llanos de aridane
# Processing Record 20 of Set 6 | saint-francois
# Processing Record 21 of Set 6 | shreveport
# Processing Record 22 of Set 6 | seydisehir
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | kolodeznyy
# Processing Record 25 of Set 6 | rongcheng
# Processing Record 26 of Set 6 | san andres
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | saint-jean-de-dieu
# City not found. Skipping...
# Processing Record 30 of Set 6 | tessalit
# Processing Record 31 of Set 6 | prado
# Processing Record 32 of Set 6 | moose factory
# Processing Record 33 of Set 6 | pella
# Processing Record 34 of Set 6 | callaway
# Processing Record 35 of Set 6 | plettenberg bay
# Processing Record 36 of Set 6 | piacabucu
# Processing Record 37 of Set 6 | belaya gora
# Processing Record 38 of Set 6 | maun
# Processing Record 39 of Set 6 | cervo
# Processing Record 40 of Set 6 | acu
# Processing Record 41 of Set 6 | aykhal
# Processing Record 42 of Set 6 | nabinagar
# Processing Record 43 of Set 6 | martapura
# Processing Record 44 of Set 6 | yantal
# Processing Record 45 of Set 6 | henties bay
# Processing Record 46 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 6 | pecsvarad
# Processing Record 48 of Set 6 | samana
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | tibiri
# Processing Record 1 of Set 7 | mangrol
# Processing Record 2 of Set 7 | shangrao
# Processing Record 3 of Set 7 | baculin
# Processing Record 4 of Set 7 | madimba
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | poum
# Processing Record 7 of Set 7 | teodoro sampaio
# Processing Record 8 of Set 7 | longyan
# Processing Record 9 of Set 7 | mahdasht
# Processing Record 10 of Set 7 | bansko
# Processing Record 11 of Set 7 | ponta delgada
# Processing Record 12 of Set 7 | finschhafen
# Processing Record 13 of Set 7 | pacifica
# Processing Record 14 of Set 7 | swan hill
# Processing Record 15 of Set 7 | bac lieu
# Processing Record 16 of Set 7 | cotonou
# Processing Record 17 of Set 7 | zilair
# Processing Record 18 of Set 7 | catalina foothills
# Processing Record 19 of Set 7 | boguchany
# Processing Record 20 of Set 7 | mareeba
# Processing Record 21 of Set 7 | denizli
# Processing Record 22 of Set 7 | old road
# City not found. Skipping...
# Processing Record 23 of Set 7 | evora
# Processing Record 24 of Set 7 | victoria
# Processing Record 25 of Set 7 | terrell
# Processing Record 26 of Set 7 | nantucket
# Processing Record 27 of Set 7 | hoopstad
# Processing Record 28 of Set 7 | sault sainte marie
# Processing Record 29 of Set 7 | georgetown
# Processing Record 30 of Set 7 | broome
# Processing Record 31 of Set 7 | beian
# Processing Record 32 of Set 7 | hithadhoo
# Processing Record 33 of Set 7 | miandrivazo
# Processing Record 34 of Set 7 | cape town
# Processing Record 35 of Set 7 | samarai
# Processing Record 36 of Set 7 | husavik
# Processing Record 37 of Set 7 | new norfolk
# Processing Record 38 of Set 7 | bandipur
# Processing Record 39 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 7 | harnosand
# Processing Record 41 of Set 7 | vidim
# Processing Record 42 of Set 7 | quatre cocos
# Processing Record 43 of Set 7 | sacramento
# Processing Record 44 of Set 7 | san quintin
# Processing Record 45 of Set 7 | gao
# Processing Record 46 of Set 7 | fort nelson
# Processing Record 47 of Set 7 | aksu
# Processing Record 48 of Set 7 | chaykovskaya
# Processing Record 49 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 7 | mikun
# Processing Record 1 of Set 8 | dingle
# Processing Record 2 of Set 8 | bara
# Processing Record 3 of Set 8 | westport
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 7 of Set 8 | alofi
# Processing Record 8 of Set 8 | port hedland
# Processing Record 9 of Set 8 | cap malheureux
# Processing Record 10 of Set 8 | kudahuvadhoo
# Processing Record 11 of Set 8 | eyl
# Processing Record 12 of Set 8 | mapiripan
# Processing Record 13 of Set 8 | coihaique
# Processing Record 14 of Set 8 | port hardy
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | nehe
# Processing Record 17 of Set 8 | tokur
# Processing Record 18 of Set 8 | san pedro de macoris
# Processing Record 19 of Set 8 | sayat
# Processing Record 20 of Set 8 | tshela
# Processing Record 21 of Set 8 | gamba
# Processing Record 22 of Set 8 | cabedelo
# Processing Record 23 of Set 8 | noumea
# Processing Record 24 of Set 8 | emba
# Processing Record 25 of Set 8 | bodden town
# Processing Record 26 of Set 8 | shimoda
# Processing Record 27 of Set 8 | inta
# Processing Record 28 of Set 8 | lovozero
# Processing Record 29 of Set 8 | khudumelapye
# Processing Record 30 of Set 8 | vostok
# Processing Record 31 of Set 8 | claveria
# Processing Record 32 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 8 | puri
# Processing Record 34 of Set 8 | conceicao da barra
# Processing Record 35 of Set 8 | anadyr
# Processing Record 36 of Set 8 | okha
# Processing Record 37 of Set 8 | ginir
# Processing Record 38 of Set 8 | ha giang
# Processing Record 39 of Set 8 | leh
# Processing Record 40 of Set 8 | chicama
# Processing Record 41 of Set 8 | alta floresta
# Processing Record 42 of Set 8 | sinnamary
# Processing Record 43 of Set 8 | tarnogskiy gorodok
# Processing Record 44 of Set 8 | ahipara
# Processing Record 45 of Set 8 | turinsk
# Processing Record 46 of Set 8 | hofn
# Processing Record 47 of Set 8 | otane
# Processing Record 48 of Set 8 | sandnessjoen
# Processing Record 49 of Set 8 | honiara
# Processing Record 50 of Set 8 | smolenka
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | bloomfield
# Processing Record 3 of Set 9 | chimbote
# Processing Record 4 of Set 9 | paita
# Processing Record 5 of Set 9 | la rioja
# Processing Record 6 of Set 9 | junction city
# Processing Record 7 of Set 9 | santa apolonia
# Processing Record 8 of Set 9 | havoysund
# Processing Record 9 of Set 9 | sorland
# Processing Record 10 of Set 9 | sauda
# Processing Record 11 of Set 9 | lumsden
# Processing Record 12 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 13 of Set 9 | taltal
# Processing Record 14 of Set 9 | zhangye
# Processing Record 15 of Set 9 | kalur kot
# Processing Record 16 of Set 9 | nanakuli
# Processing Record 17 of Set 9 | sucre
# Processing Record 18 of Set 9 | fairbanks
# Processing Record 19 of Set 9 | mingyue
# Processing Record 20 of Set 9 | tagusao
# Processing Record 21 of Set 9 | san policarpo
# Processing Record 22 of Set 9 | udachnyy
# Processing Record 23 of Set 9 | la romana
# Processing Record 24 of Set 9 | tucurui
# Processing Record 25 of Set 9 | mahebourg
# Processing Record 26 of Set 9 | bluefield
# Processing Record 27 of Set 9 | tucupita
# Processing Record 28 of Set 9 | carlyle
# Processing Record 29 of Set 9 | maniitsoq
# Processing Record 30 of Set 9 | vao
# Processing Record 31 of Set 9 | miass
# Processing Record 32 of Set 9 | pachino
# Processing Record 33 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 9 | gizo
# Processing Record 35 of Set 9 | ulaanbaatar
# Processing Record 36 of Set 9 | leningradskiy
# Processing Record 37 of Set 9 | denia
# Processing Record 38 of Set 9 | azul
# Processing Record 39 of Set 9 | hervey bay
# Processing Record 40 of Set 9 | along
# Processing Record 41 of Set 9 | esil
# Processing Record 42 of Set 9 | eureka
# Processing Record 43 of Set 9 | cayenne
# Processing Record 44 of Set 9 | meghri
# Processing Record 45 of Set 9 | belyy yar
# Processing Record 46 of Set 9 | aguas formosas
# Processing Record 47 of Set 9 | olbia
# Processing Record 48 of Set 9 | port blair
# Processing Record 49 of Set 9 | manaus
# Processing Record 50 of Set 9 | mingguang
# Processing Record 1 of Set 10 | poso
# Processing Record 2 of Set 10 | te anau
# Processing Record 3 of Set 10 | yar-sale
# Processing Record 4 of Set 10 | bonthe
# Processing Record 5 of Set 10 | dalvik
# Processing Record 6 of Set 10 | hanmer springs
# Processing Record 7 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 10 | palmer
# Processing Record 9 of Set 10 | bohl-iggelheim
# Processing Record 10 of Set 10 | ukiah
# Processing Record 11 of Set 10 | north bend
# Processing Record 12 of Set 10 | inirida
# Processing Record 13 of Set 10 | shizukuishi
# Processing Record 14 of Set 10 | college
# Processing Record 15 of Set 10 | shache
# Processing Record 16 of Set 10 | palana
# Processing Record 17 of Set 10 | nailon
# Processing Record 18 of Set 10 | neuquen
# Processing Record 19 of Set 10 | ashdod
# Processing Record 20 of Set 10 | bishop auckland
# Processing Record 21 of Set 10 | zhetybay
# City not found. Skipping...
# Processing Record 22 of Set 10 | amnat charoen
# Processing Record 23 of Set 10 | zhigalovo
# Processing Record 24 of Set 10 | maumere
# Processing Record 25 of Set 10 | imbituba
# Processing Record 26 of Set 10 | cuamba
# Processing Record 27 of Set 10 | ken caryl
# Processing Record 28 of Set 10 | tres rios
# Processing Record 29 of Set 10 | vidalia
# Processing Record 30 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 31 of Set 10 | jacksonville
# Processing Record 32 of Set 10 | sola
# Processing Record 33 of Set 10 | rognan
# Processing Record 34 of Set 10 | vanavara
# Processing Record 35 of Set 10 | ahuimanu
# Processing Record 36 of Set 10 | mucurapo
# Processing Record 37 of Set 10 | qasigiannguit
# Processing Record 38 of Set 10 | antofagasta
# Processing Record 39 of Set 10 | tres arroyos
# Processing Record 40 of Set 10 | carmarthen
# Processing Record 41 of Set 10 | viedma
# Processing Record 42 of Set 10 | lebyazhye
# Processing Record 43 of Set 10 | kapit
# Processing Record 44 of Set 10 | morehead
# Processing Record 45 of Set 10 | baoning
# Processing Record 46 of Set 10 | ust-kuyga
# Processing Record 47 of Set 10 | touros
# Processing Record 48 of Set 10 | masunga
# Processing Record 49 of Set 10 | vitim
# Processing Record 50 of Set 10 | dongsheng
# Processing Record 1 of Set 11 | concordia
# Processing Record 2 of Set 11 | nome
# Processing Record 3 of Set 11 | xai-xai
# Processing Record 4 of Set 11 | sora
# Processing Record 5 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 11 | seybaplaya
# Processing Record 7 of Set 11 | ust-tsilma
# Processing Record 8 of Set 11 | kankon
# Processing Record 9 of Set 11 | omsukchan
# Processing Record 10 of Set 11 | sobolevo
# Processing Record 11 of Set 11 | kokkola
# Processing Record 12 of Set 11 | killybegs
# Processing Record 13 of Set 11 | turkistan
# Processing Record 14 of Set 11 | turukhansk
# Processing Record 15 of Set 11 | duz
# City not found. Skipping...
# Processing Record 16 of Set 11 | rocha
# Processing Record 17 of Set 11 | filingue
# Processing Record 18 of Set 11 | evensk
# Processing Record 19 of Set 11 | ust-koksa
# Processing Record 20 of Set 11 | yarega
# Processing Record 21 of Set 11 | goksun
# Processing Record 22 of Set 11 | phayao
# Processing Record 23 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 11 | berbera
# Processing Record 25 of Set 11 | marabba
# Processing Record 26 of Set 11 | domoni
# Processing Record 27 of Set 11 | monroe
# Processing Record 28 of Set 11 | rochegda
# Processing Record 29 of Set 11 | pandharpur
# Processing Record 30 of Set 11 | marinette
# Processing Record 31 of Set 11 | bemidji
# Processing Record 32 of Set 11 | guerrero negro
# Processing Record 33 of Set 11 | manoel urbano
# Processing Record 34 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 35 of Set 11 | erenhot
# Processing Record 36 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 11 | coria
# Processing Record 38 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 11 | dali
# Processing Record 40 of Set 11 | nizhneangarsk
# Processing Record 41 of Set 11 | mizdah
# Processing Record 42 of Set 11 | norwich
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | cochrane
# Processing Record 45 of Set 11 | coari
# Processing Record 46 of Set 11 | chadiza
# Processing Record 47 of Set 11 | albanel
# Processing Record 48 of Set 11 | okhotsk
# Processing Record 49 of Set 11 | high prairie
# Processing Record 50 of Set 11 | mindelo
# Processing Record 1 of Set 12 | almaznyy
# Processing Record 2 of Set 12 | lushunkou
# City not found. Skipping...
# Processing Record 3 of Set 12 | fuerte olimpo
# Processing Record 4 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 12 | mersing
# Processing Record 7 of Set 12 | shingu
# Processing Record 8 of Set 12 | surt
# Processing Record 9 of Set 12 | shiyan
# Processing Record 10 of Set 12 | katherine
# Processing Record 11 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 12 | sivaki
# Processing Record 13 of Set 12 | jhelum
# Processing Record 14 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 15 of Set 12 | pundaguitan
# Processing Record 16 of Set 12 | ostrovnoy
# Processing Record 17 of Set 12 | kavaratti
# Processing Record 18 of Set 12 | baghdad
# Processing Record 19 of Set 12 | siilinjarvi
# Processing Record 20 of Set 12 | linares
# Processing Record 21 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 12 | zhigansk
# Processing Record 23 of Set 12 | nyimba
# Processing Record 24 of Set 12 | upington
# Processing Record 25 of Set 12 | marzuq
# Processing Record 26 of Set 12 | ellisras
# Processing Record 27 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 12 | jiexiu
# Processing Record 30 of Set 12 | ystad
# Processing Record 31 of Set 12 | ambon
# Processing Record 32 of Set 12 | keti bandar
# Processing Record 33 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 12 | caravelas
# Processing Record 35 of Set 12 | byron bay
# Processing Record 36 of Set 12 | lodja
# Processing Record 37 of Set 12 | kamaishi
# Processing Record 38 of Set 12 | quesnel
# Processing Record 39 of Set 12 | menongue
# Processing Record 40 of Set 12 | japura
# Processing Record 41 of Set 12 | ainazi
# Processing Record 42 of Set 12 | biarritz
# Processing Record 43 of Set 12 | verkhnevilyuysk
# Processing Record 44 of Set 12 | huangzhai
# Processing Record 45 of Set 12 | gerash
# Processing Record 46 of Set 12 | deputatskiy
# Processing Record 47 of Set 12 | esperance
# Processing Record 48 of Set 12 | broken hill
# Processing Record 49 of Set 12 | terrace bay
# Processing Record 50 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 13 | jumla
# Processing Record 2 of Set 13 | le pont-de-claix
# Processing Record 3 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 4 of Set 13 | bana
# Processing Record 5 of Set 13 | talara
# Processing Record 6 of Set 13 | hamilton
# Processing Record 7 of Set 13 | preobrazheniye
# Processing Record 8 of Set 13 | lac du bonnet
# Processing Record 9 of Set 13 | yenagoa
# Processing Record 10 of Set 13 | shenzhen
# Processing Record 11 of Set 13 | great yarmouth
# Processing Record 12 of Set 13 | zalegoshch
# Processing Record 13 of Set 13 | boa vista
# Processing Record 14 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 15 of Set 13 | lagoa
# Processing Record 16 of Set 13 | moron
# Processing Record 17 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 13 | acarau
# Processing Record 19 of Set 13 | clyde river
# Processing Record 20 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 13 | grand gaube
# Processing Record 22 of Set 13 | baruun-urt
# Processing Record 23 of Set 13 | sale
# Processing Record 24 of Set 13 | grenaa
# Processing Record 25 of Set 13 | brainerd
# Processing Record 26 of Set 13 | belvedere marittimo
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | praia
# Processing Record 29 of Set 13 | muli
# Processing Record 30 of Set 13 | abu kamal
# Processing Record 31 of Set 13 | gainesville
# Processing Record 32 of Set 13 | port pirie
# Processing Record 33 of Set 13 | akdepe
# Processing Record 34 of Set 13 | vila velha
# Processing Record 35 of Set 13 | sao joao da barra
# Processing Record 36 of Set 13 | emilio carranza
# Processing Record 37 of Set 13 | khasan
# Processing Record 38 of Set 13 | izhma
# Processing Record 39 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 13 | paamiut
# Processing Record 41 of Set 13 | de aar
# Processing Record 42 of Set 13 | egvekinot
# Processing Record 43 of Set 13 | reforma
# Processing Record 44 of Set 13 | atar
# Processing Record 45 of Set 13 | yulara
# Processing Record 46 of Set 13 | matagami
# Processing Record 47 of Set 13 | port keats
# Processing Record 48 of Set 13 | aykino
# Processing Record 49 of Set 13 | bukama
# Processing Record 50 of Set 13 | manokwari
# Processing Record 1 of Set 14 | areosa
# Processing Record 2 of Set 14 | palu
# Processing Record 3 of Set 14 | igarka
# Processing Record 4 of Set 14 | langarud
# Processing Record 5 of Set 14 | bandarbeyla
# Processing Record 6 of Set 14 | kamenka
# Processing Record 7 of Set 14 | grenfell
# Processing Record 8 of Set 14 | coxim
# Processing Record 9 of Set 14 | gamboma
# Processing Record 10 of Set 14 | ruteng
# Processing Record 11 of Set 14 | mineral wells
# Processing Record 12 of Set 14 | chilca
# Processing Record 13 of Set 14 | guiyang
# Processing Record 14 of Set 14 | weatherford
# Processing Record 15 of Set 14 | abu samrah
# Processing Record 16 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 17 of Set 14 | waipawa
# Processing Record 18 of Set 14 | mandalgovi
# Processing Record 19 of Set 14 | serebryanyy bor
# Processing Record 20 of Set 14 | coquimbo
# Processing Record 21 of Set 14 | conde
# Processing Record 22 of Set 14 | kabo
# Processing Record 23 of Set 14 | dedza
# Processing Record 24 of Set 14 | tingo maria
# Processing Record 25 of Set 14 | saint-joseph
# Processing Record 26 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 14 | ormara
# Processing Record 28 of Set 14 | ingham
# Processing Record 29 of Set 14 | taupo
# Processing Record 30 of Set 14 | chumikan
# Processing Record 31 of Set 14 | majene
# Processing Record 32 of Set 14 | port hawkesbury
# Processing Record 33 of Set 14 | lagos
# Processing Record 34 of Set 14 | oksfjord
# Processing Record 35 of Set 14 | meulaboh
# Processing Record 36 of Set 14 | rawson
# Processing Record 37 of Set 14 | kolokani
# Processing Record 38 of Set 14 | baykalsk
# Processing Record 39 of Set 14 | ozuluama
# Processing Record 40 of Set 14 | bagacay
# Processing Record 41 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 14 | kariba
# Processing Record 43 of Set 14 | chapais
# Processing Record 44 of Set 14 | marsh harbour
# Processing Record 45 of Set 14 | kargasok
# Processing Record 46 of Set 14 | carauari
# Processing Record 47 of Set 14 | zhezkazgan
# Processing Record 48 of Set 14 | washington
# Processing Record 49 of Set 14 | lasa
# Processing Record 50 of Set 14 | taonan
# Processing Record 1 of Set 15 | todos santos
# Processing Record 2 of Set 15 | buraydah
# Processing Record 3 of Set 15 | saint anthony
# Processing Record 4 of Set 15 | sedalia
# Processing Record 5 of Set 15 | tupiza
# Processing Record 6 of Set 15 | levski
# Processing Record 7 of Set 15 | leghorn
# City not found. Skipping...
# Processing Record 8 of Set 15 | dzilam gonzalez
# Processing Record 9 of Set 15 | kiruna
# Processing Record 10 of Set 15 | ballina
# Processing Record 11 of Set 15 | pochutla
# Processing Record 12 of Set 15 | bekhteyevka
# Processing Record 13 of Set 15 | san marcos
# Processing Record 14 of Set 15 | richards bay
# Processing Record 15 of Set 15 | zeulenroda
# Processing Record 16 of Set 15 | sabha
# Processing Record 17 of Set 15 | sharan
# Processing Record 18 of Set 15 | san juan
# Processing Record 19 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 15 | shatalovo
# Processing Record 21 of Set 15 | latung
# Processing Record 22 of Set 15 | heyang
# Processing Record 23 of Set 15 | takoradi
# Processing Record 24 of Set 15 | santa marta
# Processing Record 25 of Set 15 | kalengwa
# Processing Record 26 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 27 of Set 15 | saint-augustin
# Processing Record 28 of Set 15 | perth
# Processing Record 29 of Set 15 | asau
# Processing Record 30 of Set 15 | jijiga
# Processing Record 31 of Set 15 | lazaro cardenas
# Processing Record 32 of Set 15 | inuvik
# Processing Record 33 of Set 15 | porto empedocle
# Processing Record 34 of Set 15 | gushikawa
# Processing Record 35 of Set 15 | togur
# Processing Record 36 of Set 15 | nisia floresta
# Processing Record 37 of Set 15 | donskoye
# Processing Record 38 of Set 15 | tupik
# Processing Record 39 of Set 15 | smirnykh
# Processing Record 40 of Set 15 | morros
# Processing Record 41 of Set 15 | merauke
# Processing Record 42 of Set 15 | arkhangelskoye
# Processing Record 43 of Set 15 | naze
# Processing Record 44 of Set 15 | dodge city
# Processing Record 45 of Set 15 | cedar city
# Processing Record 46 of Set 15 | mackay
# Processing Record 47 of Set 15 | trier
# Processing Record 48 of Set 15 | neftcala
# Processing Record 49 of Set 15 | upata
# Processing Record 50 of Set 15 | bonnyville
# Processing Record 1 of Set 16 | bafia
# Processing Record 2 of Set 16 | qingdao
# Processing Record 3 of Set 16 | constitucion
# Processing Record 4 of Set 16 | uglekamensk
# Processing Record 5 of Set 16 | nador
# Processing Record 6 of Set 16 | ambovombe
# Processing Record 7 of Set 16 | greeley
# Processing Record 8 of Set 16 | sao pedro
# Processing Record 9 of Set 16 | biltine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Santa Rosa  14.3122  121.1114     80.01        83          20
# 1       Mataura -46.1927  168.8643     52.43        88          99
# 2       Codajas  -3.8367  -62.0569     89.13        60          72
# 3          Melo -32.3667  -54.1833     84.94        46           0
# 4  San Patricio  28.0170  -97.5169     64.99        59           1
# 5         Vaini -21.2000 -175.2000     77.00        94          75
# 6    Tarko-Sale  64.9225   77.7850     16.07        97         100
# 7    Bredasdorp -34.5322   20.0403     69.80        52          89
# 8  Oktyabrskoye  43.0645   44.7417     26.60       100          90
# 9        Matata -37.8833  176.7500     59.00        91          76
#
#    Wind Speed Country Current Description
# 0        3.44      PH          few clouds
# 1        1.88      NZ     overcast clouds
# 2        4.65      BR       moderate rain
# 3        2.10      UY           clear sky
# 4       13.80      US           clear sky
# 5       10.36      TO          light rain
# 6       19.22      RU          light snow
# 7       10.36      ZA     overcast clouds
# 8        2.24      RU     overcast clouds
# 9        1.01      NZ       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Santa Rosa      PH  14.3122  121.1114     80.01        83          20
# 1         Mataura      NZ -46.1927  168.8643     52.43        88          99
# 2         Codajas      BR  -3.8367  -62.0569     89.13        60          72
# 3            Melo      UY -32.3667  -54.1833     84.94        46           0
# 4    San Patricio      US  28.0170  -97.5169     64.99        59           1
# ..            ...     ...      ...       ...       ...       ...         ...
# 683         Nador      MA  35.1740   -2.9287     59.00        72          75
# 684     Ambovombe      MG -25.1667   46.0833     77.92        90          22
# 685       Greeley      US  40.4233 -104.7091     44.01        57           8
# 686     Sao Pedro      BR -22.5486  -47.9139     80.69        58          12
# 687       Biltine      TD  14.5333   20.9167     77.59        15           7
#
#      Wind Speed Current Description
# 0          3.44          few clouds
# 1          1.88     overcast clouds
# 2          4.65       moderate rain
# 3          2.10           clear sky
# 4         13.80           clear sky
# ..          ...                 ...
# 683       18.41       broken clouds
# 684        9.95          light rain
# 685        1.01           clear sky
# 686        7.14          few clouds
# 687       10.20           clear sky
#
# [688 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
